# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_rows', 100)
import matplotlib
import matplotlib.pyplot as plt 
import seaborn as sns
# %matplotlib inline
from datetime import datetime
import time

# %%
zri = pd.read_csv('./data/Zip_Zri_MultiFamilyResidenceRental.csv')

# %%
zri.head()
# Out:
#    RegionID  RegionName      City State                             Metro  \
# 0     61639       10025  New York    NY       New York-Newark-Jersey City
# 1     84654       60657   Chicago    IL          Chicago-Naperville-Elgin
# 2     61637       10023  New York    NY       New York-Newark-Jersey City
# 3     91982       77494      Katy    TX  Houston-The Woodlands-Sugar Land
# 4     84616       60614   Chicago    IL          Chicago-Naperville-Elgin
#
#         CountyName  SizeRank  2010-09  2010-10  2010-11  ...  2019-04  \
# 0  New York County         1   2930.0   2952.0   2926.0  ...   3484.0
# 1      Cook County         2   1447.0   1465.0   1469.0  ...   1731.0
# 2  New York County         3   2797.0   2811.0   2813.0  ...   3449.0
# 3    Harris County         4      NaN      NaN      NaN  ...   1226.0
# 4      Cook County         5   1437.0   1469.0   1490.0  ...   1888.0
#
#    2019-05  2019-06  2019-07  2019-08  2019-09  2019-10  2019-11  2019-12  \
# ...

# %% [markdown]
# ### Storing zip codes of each Florida metro areas in a list

# %%
miami_zip=sorted(zri[zri["Metro"]=="Miami-Fort Lauderdale-West Palm Beach"].RegionName.unique().tolist())
# %store miami_zip
# Out:
# Stored 'miami_zip' (list)

# %%
orlando_zip=sorted(zri[zri["Metro"]=="Orlando-Kissimmee-Sanford"].RegionName.unique().tolist())
# %store orlando_zip
# Out:
# Stored 'orlando_zip' (list)

# %%
tampa_zip=sorted(zri[zri["Metro"]=="Tampa-St. Petersburg-Clearwater"].RegionName.unique().tolist())
# %store tampa_zip
# Out:
# Stored 'tampa_zip' (list)

# %%
jax_zip=sorted(zri[zri["Metro"]=="Jacksonville"].RegionName.unique().tolist())
# %store jax_zip
# Out:
# Stored 'jax_zip' (list)

# %%
miami_zip
# Out:
# [33004,
#  33009,
#  33010,
#  33020,
#  33021,
#  33024,
#  33025,
#  33027,
#  33033,
#  33060,
#  33062,
#  33064,
#  33065,
#  33066,
#  33068,
#  33125,
#  33126,
#  33127,
#  33130,
#  33131,
#  33132,
#  33133,
#  33134,
#  33135,
#  33137,
#  33138,
#  33139,
#  33140,
#  33141,
#  33142,
#  33143,
#  33145,
#  33146,
#  33147,
#  33150,
#  33154,
#  33156,
#  33157,
#  33160,
#  33161,
#  33172,
#  33178,
#  33179,
#  33180,
#  33186,
#  33196,
#  33301,
#  33304,
#  33305,
#  33308,
#  33311,
#  33312,
#  33313,
#  33314,
#  33315,
#  33316,
#  33323,
#  33324,
#  33334,
#  33401,
#  33404,
#  33407,
#  33413,
#  33414,
#  33418,
#  33432,
#  33433,
#  33435,
#  33436,
#  33444,
#  33445,
#  33458,
#  33460,
#  33461,
#  33483]

# %%
orlando_zip
# Out:
# [32701,
#  32703,
#  32714,
#  32751,
#  32765,
#  32771,
#  32792,
#  32801,
#  32803,
#  32806,
#  32807,
#  32810,
#  32811,
#  32812,
#  32817,
#  32821,
#  32822,
#  32825,
#  32826,
#  32827,
#  32828,
#  32835,
#  32837,
#  32839,
#  34711,
#  34747,
#  34787]

# %%
tampa_zip
# Out:
# [33510,
#  33511,
#  33578,
#  33602,
#  33604,
#  33605,
#  33606,
#  33607,
#  33611,
#  33612,
#  33613,
#  33615,
#  33617,
#  33626,
#  33634,
#  33701,
#  33702,
#  33705,
#  33706,
#  33707,
#  33708,
#  33712,
#  33716,
#  33755,
#  33756,
#  33759,
#  33764,
#  33771,
#  33774,
#  34683,
#  34684,
#  34698]

# %%
jax_zip
# Out:
# [32204, 32205, 32206, 32207, 32209, 32216, 32224, 32225, 32246, 32250, 32256]

# %% [markdown]
# # Visualization on the Zillow Rent Index

# %%
df_metro_fl=zri[zri["Metro"].isin(["Miami-Fort Lauderdale-West Palm Beach",
                       "Orlando-Kissimmee-Sanford", 
                       "Tampa-St. Petersburg-Clearwater",
                      "Jacksonville"])]

# %%
df_metro_fl.columns.tolist()
#There're 7 columns which are not "months"
# Out:
# ['RegionID',
#  'RegionName',
#  'City',
#  'State',
#  'Metro',
#  'CountyName',
#  'SizeRank',
#  '2010-09',
#  '2010-10',
#  '2010-11',
#  '2010-12',
#  '2011-01',
#  '2011-02',
#  '2011-03',
#  '2011-04',
#  '2011-05',
#  '2011-06',
#  '2011-07',
#  '2011-08',
#  '2011-09',
#  '2011-10',
#  '2011-11',
#  '2011-12',
#  '2012-01',
#  '2012-02',
#  '2012-03',
#  '2012-04',
#  '2012-05',
#  '2012-06',
#  '2012-07',
#  '2012-08',
#  '2012-09',
#  '2012-10',
#  '2012-11',
#  '2012-12',
#  '2013-01',
#  '2013-02',
#  '2013-03',
#  '2013-04',
#  '2013-05',
#  '2013-06',
#  '2013-07',
#  '2013-08',
#  '2013-09',
#  '2013-10',
#  '2013-11',
#  '2013-12',
#  '2014-01',
#  '2014-02',
#  '2014-03',
#  '2014-04',
#  '2014-05',
#  '2014-06',
#  '2014-07',
#  '2014-08',
#  '2014-09',
#  '2014-10',
#  '2014-11',
#  '2014-12',
#  '2015-01',
#  '2015-02',
#  '2015-03',
#  '2015-04',
#  '2015-05',
#  '2015-06',
#  '2015-07',
#  '2015-08',
#  '2015-09',
#  '2015-10',
#  '2015-11',
#  '2015-12',
# ...

# %%
df_metro_fl.shape #145 zip codes in all 4 metro areas
# Out:
# (145, 120)

# %%
df_metro_fl
# Out:
#       RegionID  RegionName               City State  \
# 71       72463       33160  Sunny Isles Beach    FL
# 72       73221       34787      Winter Garden    FL
# 85       72363       33025            Miramar    FL
# 90       72442       33139        Miami Beach    FL
# 127      72362       33024     Pembroke Pines    FL
# ...        ...         ...                ...   ...
# 1752     72534       33315    Fort Lauderdale    FL
# 1753     72251       32827            Orlando    FL
# 1782     72580       33413         Greenacres    FL
# 1802     72449       33146       Coral Gables    FL
# 1820     71858       32204       Jacksonville    FL
#
#                                       Metro         CountyName  SizeRank  \
# 71    Miami-Fort Lauderdale-West Palm Beach  Miami-Dade County        72
# 72                Orlando-Kissimmee-Sanford      Orange County        73
# 85    Miami-Fort Lauderdale-West Palm Beach     Broward County        86
# ...

# %%
df_metro_fl_trans=df_metro_fl.T

# %%
df_metro_fl_trans
# Out:
#                                              71                         72    \
# RegionID                                    72463                      73221
# RegionName                                  33160                      34787
# City                            Sunny Isles Beach              Winter Garden
# State                                          FL                         FL
# Metro       Miami-Fort Lauderdale-West Palm Beach  Orlando-Kissimmee-Sanford
# ...                                           ...                        ...
# 2019-09                                    2037.0                     1459.0
# 2019-10                                    2021.0                     1473.0
# 2019-11                                    2020.0                     1487.0
# 2019-12                                    2054.0                     1443.0
# 2020-01                                       NaN                     1433.0
#
# ...

# %%
df_metro_fl_trans.columns = df_metro_fl_trans.iloc[1]

# %%
df_metro_fl_trans
# Out:
# RegionName                                  33160                      34787  \
# RegionID                                    72463                      73221
# RegionName                                  33160                      34787
# City                            Sunny Isles Beach              Winter Garden
# State                                          FL                         FL
# Metro       Miami-Fort Lauderdale-West Palm Beach  Orlando-Kissimmee-Sanford
# ...                                           ...                        ...
# 2019-09                                    2037.0                     1459.0
# 2019-10                                    2021.0                     1473.0
# 2019-11                                    2020.0                     1487.0
# 2019-12                                    2054.0                     1443.0
# 2020-01                                       NaN                     1433.0
#
# ...

# %%
zri_by_fl_zip=df_metro_fl_trans.drop(["RegionID", 
                                "RegionName", 
                                "City", "State", "Metro", 
                                "CountyName", "SizeRank"], axis=0)

# %%
zri_by_fl_zip
# Out:
# RegionName   33160   34787   33025   33139   33024   32256   34711   33009  \
# 2010-09     1622.0     NaN  1106.0  1388.0     NaN   706.0     NaN  1173.0
# 2010-10     1658.0     NaN  1120.0  1423.0     NaN   726.0     NaN  1190.0
# 2010-11        NaN     NaN  1133.0  1449.0     NaN   733.0     NaN  1203.0
# 2010-12        NaN     NaN  1155.0  1488.0     NaN   736.0     NaN  1222.0
# 2011-01     1743.0     NaN  1176.0  1517.0     NaN   752.0     NaN  1232.0
# ...            ...     ...     ...     ...     ...     ...     ...     ...
# 2019-09     2037.0  1459.0  1622.0  1992.0  1537.0  1233.0     NaN  1630.0
# 2019-10     2021.0  1473.0  1610.0  1996.0  1527.0  1247.0  1370.0  1627.0
# 2019-11     2020.0  1487.0  1629.0  1939.0  1525.0  1274.0  1388.0  1632.0
# 2019-12     2054.0  1443.0  1636.0  1958.0  1544.0  1261.0  1397.0  1613.0
# 2020-01        NaN  1433.0  1611.0     NaN  1527.0  1258.0  1407.0  1605.0
#
# ...

# %%
zri_by_fl_zip.columns = zri_by_fl_zip.columns.astype(str)

# %%
#Plotting for a particular zip code
plt.figure(figsize = (32, 16))
plt.plot(zri_by_fl_zip.index, zri_by_fl_zip["33160"])
plt.xticks(np.arange(4,112, 12), range(2011, 2020, 1), size=45)
plt.yticks(size=40)
plt.title("Zillow Rent Index ($) Over Time for the Zip Code 33160", size=50)
sns.set_style("whitegrid")
plt.grid(True, color = "grey", linewidth = "0.9", linestyle = "-.")
plt.show()

# %% [markdown]
# ### Making seperate dataframe for each of the 4 metro areas

# %% [markdown]
# # Max, Min and Average Zillow Rent Index Over Time: Miami

# %%
df_miami=df_metro_fl[df_metro_fl["Metro"]=="Miami-Fort Lauderdale-West Palm Beach"]

# %%
df_miami.head()
# Out:
#      RegionID  RegionName               City State  \
# 71      72463       33160  Sunny Isles Beach    FL
# 85      72363       33025            Miramar    FL
# 90      72442       33139        Miami Beach    FL
# 127     72362       33024     Pembroke Pines    FL
# 160     72347       33009         Hallandale    FL
#
#                                      Metro         CountyName  SizeRank  \
# 71   Miami-Fort Lauderdale-West Palm Beach  Miami-Dade County        72
# 85   Miami-Fort Lauderdale-West Palm Beach     Broward County        86
# 90   Miami-Fort Lauderdale-West Palm Beach  Miami-Dade County        91
# 127  Miami-Fort Lauderdale-West Palm Beach     Broward County       128
# 160  Miami-Fort Lauderdale-West Palm Beach     Broward County       161
#
#      2010-09  2010-10  2010-11  ...  2019-04  2019-05  2019-06  2019-07  \
# 71    1622.0   1658.0      NaN  ...   2028.0   2016.0   2016.0   2023.0
# 85    1106.0   1120.0   1133.0  ...   1614.0   1617.0   1616.0   1618.0
# ...

# %%
df_miami.groupby("Metro").mean()
# Out:
#                                        RegionID    RegionName    SizeRank  \
# Metro
# Miami-Fort Lauderdale-West Palm Beach  72481.12  33216.026667  842.266667
#
#                                            2010-09  2010-10  2010-11  \
# Metro
# Miami-Fort Lauderdale-West Palm Beach  1326.064516  1368.44  1334.56
#
#                                            2010-12      2011-01      2011-02  \
# Metro
# Miami-Fort Lauderdale-West Palm Beach  1360.321429  1386.516129  1405.172414
#
#                                            2011-03  ...      2019-04  \
# Metro                                               ...
# Miami-Fort Lauderdale-West Palm Beach  1395.354839  ...  1720.709677
#
#                                           2019-05      2019-06      2019-07  \
# Metro
# Miami-Fort Lauderdale-West Palm Beach  1720.21875  1715.681159  1720.394366
#
#                                            2019-08      2019-09      2019-10  \
# Metro
# ...

# %%
#Taking only the "months" columns
df_miami_mean=df_miami.groupby("Metro").mean().iloc[: , 3:]
df_miami_mean=df_miami_mean.T

# %%
df_miami_mean.columns=["Mean_Rent"]
df_miami_mean
# Out:
#            Mean_Rent
# 2010-09  1326.064516
# 2010-10  1368.440000
# 2010-11  1334.560000
# 2010-12  1360.321429
# 2011-01  1386.516129
# ...              ...
# 2019-09  1720.194444
# 2019-10  1729.477612
# 2019-11  1726.417910
# 2019-12  1735.029412
# 2020-01  1720.764706
#
# [113 rows x 1 columns]

# %%
df_miami_max=df_miami.groupby("Metro").max().iloc[: , 6:].T

# %%
df_miami_max.columns=["Max_Rent"]

# %%
df_miami_max
# Out:
#          Max_Rent
# 2010-09    1622.0
# 2010-10    1658.0
# 2010-11    1678.0
# 2010-12    1717.0
# 2011-01    1743.0
# ...           ...
# 2019-09    2283.0
# 2019-10    2286.0
# 2019-11    2259.0
# 2019-12    2392.0
# 2020-01    2373.0
#
# [113 rows x 1 columns]

# %%
df_miami_min=df_miami.groupby("Metro").min().iloc[: , 6:].T
df_miami_min.columns=["Min_Rent"]
df_miami_min
# Out:
#          Min_Rent
# 2010-09     957.0
# 2010-10    1018.0
# 2010-11    1009.0
# 2010-12    1014.0
# 2011-01    1029.0
# ...           ...
# 2019-09    1369.0
# 2019-10    1385.0
# 2019-11    1351.0
# 2019-12    1372.0
# 2020-01    1361.0
#
# [113 rows x 1 columns]

# %%
df_miami_mean.shape
# Out:
# (113, 1)

# %%
plt.figure(figsize = (32, 16))

plt.plot(df_miami_max.index, df_miami_max["Max_Rent"], color='r')
plt.plot(df_miami_mean.index, df_miami_mean["Mean_Rent"], color='b')
plt.plot(df_miami_min.index, df_miami_min["Min_Rent"], color='g')

plt.xticks(np.arange(4,112, 12), range(2011, 2020, 1), size=45)
#speificy where the first instance starts, 5th month in this case 
#plt.xticks(rotation=45, size=45)
plt.yticks(size=40)
plt.title("Max, Min and Average Zillow Rent Index ($) Over Time for Miami", size=50)
plt.legend(['Max','Average','Min'], prop={'size': 40})
sns.set_style("whitegrid")
plt.grid(True, color = "grey", linewidth = "0.9", linestyle = "-.")
plt.show()

# %% [markdown]
# # Max, Min and Average Zillow Rent Index Over Time: Orlando

# %%
df_orlando=df_metro_fl[df_metro_fl["Metro"]=="Orlando-Kissimmee-Sanford"]

# %%
df_orlando.head()
# Out:
#      RegionID  RegionName           City State                      Metro  \
# 72      73221       34787  Winter Garden    FL  Orlando-Kissimmee-Sanford
# 158     73183       34711       Clermont    FL  Orlando-Kissimmee-Sanford
# 178     72247       32822        Orlando    FL  Orlando-Kissimmee-Sanford
# 229     72252       32828        Orlando    FL  Orlando-Kissimmee-Sanford
# 287     72199       32765         Oviedo    FL  Orlando-Kissimmee-Sanford
#
#           CountyName  SizeRank  2010-09  2010-10  2010-11  ...  2019-04  \
# 72     Orange County        73      NaN      NaN      NaN  ...      NaN
# 158      Lake County       159      NaN      NaN      NaN  ...      NaN
# 178    Orange County       179    728.0    732.0    738.0  ...   1320.0
# 229    Orange County       230      NaN      NaN      NaN  ...   1477.0
# 287  Seminole County       288      NaN      NaN      NaN  ...   1336.0
#
#      2019-05  2019-06  2019-07  2019-08  2019-09  2019-10  2019-11  2019-12  \
# ...

# %%
df_orlando.groupby("Metro").mean()
# Out:
#                                RegionID    RegionName    SizeRank  2010-09  \
# Metro
# Orlando-Kissimmee-Sanford  72334.666667  33013.666667  865.814815  716.625
#
#                               2010-10     2010-11  2010-12     2011-01  \
# Metro
# Orlando-Kissimmee-Sanford  711.714286  722.777778   726.25  741.666667
#
#                               2011-02  2011-03  ...      2019-04      2019-05  \
# Metro                                           ...
# Orlando-Kissimmee-Sanford  752.444444    767.3  ...  1364.095238  1370.727273
#
#                                2019-06      2019-07      2019-08      2019-09  \
# Metro
# Orlando-Kissimmee-Sanford  1370.857143  1385.454545  1390.521739  1397.916667
#
#                                2019-10   2019-11  2019-12  2020-01
# Metro
# Orlando-Kissimmee-Sanford  1388.695652  1409.625  1408.68  1409.64
#
# [1 rows x 116 columns]

# %%
#Taking only the "months" columns
df_orlando_mean=df_orlando.groupby("Metro").mean().iloc[: , 3:]
df_orlando_mean=df_orlando_mean.T

# %%
df_orlando_mean.columns=["Mean_Rent"]
df_orlando_mean
# Out:
#            Mean_Rent
# 2010-09   716.625000
# 2010-10   711.714286
# 2010-11   722.777778
# 2010-12   726.250000
# 2011-01   741.666667
# ...              ...
# 2019-09  1397.916667
# 2019-10  1388.695652
# 2019-11  1409.625000
# 2019-12  1408.680000
# 2020-01  1409.640000
#
# [113 rows x 1 columns]

# %%
df_orlando_max=df_orlando.groupby("Metro").max().iloc[: , 6:].T

# %%
df_orlando_max.columns=["Max_Rent"]

# %%
df_orlando_max
# Out:
#          Max_Rent
# 2010-09     797.0
# 2010-10     799.0
# 2010-11     793.0
# 2010-12     790.0
# 2011-01     799.0
# ...           ...
# 2019-09    1635.0
# 2019-10    1580.0
# 2019-11    1693.0
# 2019-12    1700.0
# 2020-01    1703.0
#
# [113 rows x 1 columns]

# %%
df_orlando_min=df_orlando.groupby("Metro").min().iloc[: , 6:].T
df_orlando_min.columns=["Min_Rent"]
df_orlando_min
# Out:
#          Min_Rent
# 2010-09     646.0
# 2010-10     633.0
# 2010-11     626.0
# 2010-12     630.0
# 2011-01     642.0
# ...           ...
# 2019-09    1181.0
# 2019-10    1193.0
# 2019-11    1206.0
# 2019-12    1204.0
# 2020-01    1212.0
#
# [113 rows x 1 columns]

# %%
df_orlando_mean.shape
# Out:
# (113, 1)

# %%
plt.figure(figsize = (32, 16))

plt.plot(df_orlando_max.index, df_orlando_max["Max_Rent"], color='r')
plt.plot(df_orlando_mean.index, df_orlando_mean["Mean_Rent"], color='b')
plt.plot(df_orlando_min.index, df_orlando_min["Min_Rent"], color='g')

plt.xticks(np.arange(4,112, 12), range(2011, 2020, 1), size=45)
#speificy where the first instance starts, 5th month in this case 
#plt.xticks(rotation=45, size=45)
plt.yticks(size=40)
plt.title("Max, Min and Average Zillow Rent Index ($) Over Time for Orlando", size=50)
plt.legend(['Max','Average','Min'], prop={'size': 40})
sns.set_style("whitegrid")
plt.grid(True, color = "grey", linewidth = "0.9", linestyle = "-.")
plt.show()

# %% [markdown]
# # Max, Min and Average Zillow Rent Index Over Time: Tampa

# %%
df_tampa=df_metro_fl[df_metro_fl["Metro"]=="Tampa-St. Petersburg-Clearwater"]

# %%
df_tampa.head()
# Out:
#      RegionID  RegionName              City State  \
# 296     72653       33511           Brandon    FL
# 314    399576       33578         Riverview    FL
# 399     73181       34698           Dunedin    FL
# 522     72718       33615  Town 'n' Country    FL
# 534     72720       33617    Temple Terrace    FL
#
#                                Metro           CountyName  SizeRank  2010-09  \
# 296  Tampa-St. Petersburg-Clearwater  Hillsborough County       297      NaN
# 314  Tampa-St. Petersburg-Clearwater  Hillsborough County       315      NaN
# 399  Tampa-St. Petersburg-Clearwater      Pinellas County       400    849.0
# 522  Tampa-St. Petersburg-Clearwater  Hillsborough County       523      NaN
# 534  Tampa-St. Petersburg-Clearwater  Hillsborough County       535      NaN
#
#      2010-10  2010-11  ...  2019-04  2019-05  2019-06  2019-07  2019-08  \
# 296      NaN      NaN  ...   1250.0   1255.0   1261.0   1272.0   1279.0
# ...

# %%
df_tampa.groupby("Metro").mean()
# Out:
#                                    RegionID  RegionName   SizeRank  \
# Metro
# Tampa-St. Petersburg-Clearwater  82999.1875   33757.875  1101.1875
#
#                                     2010-09  2010-10     2010-11  2010-12  \
# Metro
# Tampa-St. Petersburg-Clearwater  897.384615    902.5  900.142857    894.6
#
#                                     2011-01     2011-02     2011-03  ...  \
# Metro                                                                ...
# Tampa-St. Petersburg-Clearwater  893.933333  894.066667  886.142857  ...
#
#                                      2019-04      2019-05  2019-06  \
# Metro
# Tampa-St. Petersburg-Clearwater  1283.392857  1283.821429   1281.4
#
#                                      2019-07     2019-08  2019-09  \
# Metro
# Tampa-St. Petersburg-Clearwater  1282.129032  1285.16129  1285.25
#
#                                      2019-10     2019-11     2019-12  \
# Metro
# Tampa-St. Petersburg-Clearwater  1312.233333  1307.09375  1311.84375
# ...

# %%
#Taking only the "months" columns
df_tampa_mean=df_tampa.groupby("Metro").mean().iloc[: , 3:]
df_tampa_mean=df_tampa_mean.T

# %%
df_tampa_mean.columns=["Mean_Rent"]
df_tampa_mean
# Out:
#            Mean_Rent
# 2010-09   897.384615
# 2010-10   902.500000
# 2010-11   900.142857
# 2010-12   894.600000
# 2011-01   893.933333
# ...              ...
# 2019-09  1285.250000
# 2019-10  1312.233333
# 2019-11  1307.093750
# 2019-12  1311.843750
# 2020-01  1297.322581
#
# [113 rows x 1 columns]

# %%
df_tampa_max=df_tampa.groupby("Metro").max().iloc[: , 6:].T

# %%
df_tampa_max.columns=["Max_Rent"]

# %%
df_tampa_max
# Out:
#          Max_Rent
# 2010-09    1170.0
# 2010-10    1177.0
# 2010-11    1176.0
# 2010-12    1180.0
# 2011-01    1180.0
# ...           ...
# 2019-09    1881.0
# 2019-10    1898.0
# 2019-11    1934.0
# 2019-12    1936.0
# 2020-01    1670.0
#
# [113 rows x 1 columns]

# %%
df_tampa_min=df_tampa.groupby("Metro").min().iloc[: , 6:].T
df_tampa_min.columns=["Min_Rent"]
df_tampa_min
# Out:
#          Min_Rent
# 2010-09     737.0
# 2010-10     752.0
# 2010-11     757.0
# 2010-12     762.0
# 2011-01     767.0
# ...           ...
# 2019-09    1061.0
# 2019-10    1084.0
# 2019-11    1105.0
# 2019-12    1080.0
# 2020-01    1067.0
#
# [113 rows x 1 columns]

# %%
df_tampa_mean.shape
# Out:
# (113, 1)

# %%
plt.figure(figsize = (32, 16))

plt.plot(df_tampa_max.index, df_tampa_max["Max_Rent"], color='r')
plt.plot(df_tampa_mean.index, df_tampa_mean["Mean_Rent"], color='b')
plt.plot(df_tampa_min.index, df_tampa_min["Min_Rent"], color='g')

plt.xticks(np.arange(4, 112, 12), range(2011, 2020, 1), size=45)
#speificy where the first instance starts, 5th month in this case 
#plt.xticks(rotation=45, size=45)
plt.yticks(size=40)
plt.title("Max, Min and Average Zillow Rent Index ($) Over Time for Tampa", size=50)
plt.legend(['Max','Average','Min'], prop={'size': 40})
sns.set_style("whitegrid")
plt.grid(True, color = "grey", linewidth = "0.9", linestyle = "-.")
plt.show()

# %% [markdown]
# # Max, Min and Average Zillow Rent Index Over Time: Jacksonville

# %%
df_jax=df_metro_fl[df_metro_fl["Metro"]=="Jacksonville"]

# %%
df_jax.head()
# Out:
#      RegionID  RegionName          City State         Metro    CountyName  \
# 153     71902       32256  Jacksonville    FL  Jacksonville  Duval County
# 230     71878       32225  Jacksonville    FL  Jacksonville  Duval County
# 266     71897       32246  Jacksonville    FL  Jacksonville  Duval County
# 523     71869       32216  Jacksonville    FL  Jacksonville  Duval County
# 661     71877       32224  Jacksonville    FL  Jacksonville  Duval County
#
#      SizeRank  2010-09  2010-10  2010-11  ...  2019-04  2019-05  2019-06  \
# 153       154    706.0    726.0    733.0  ...   1209.0   1210.0   1214.0
# 230       231      NaN      NaN      NaN  ...   1121.0   1128.0   1131.0
# 266       267      NaN      NaN      NaN  ...   1333.0   1333.0   1329.0
# 523       524      NaN      NaN      NaN  ...      NaN      NaN      NaN
# 661       662      NaN      NaN      NaN  ...   1322.0   1325.0   1326.0
#
#      2019-07  2019-08  2019-09  2019-10  2019-11  2019-12  2020-01
# ...

# %%
df_jax.groupby("Metro").mean()
# Out:
#                   RegionID    RegionName    SizeRank  2010-09  2010-10  \
# Metro
# Jacksonville  71874.818182  32222.545455  828.454545    706.0    726.0
#
#               2010-11  2010-12  2011-01  2011-02  2011-03  ...  2019-04  \
# Metro                                                      ...
# Jacksonville    733.0    736.0    752.0    772.0    792.0  ...   1143.0
#
#                   2019-05      2019-06      2019-07      2019-08      2019-09  \
# Metro
# Jacksonville  1145.111111  1149.666667  1154.333333  1155.888889  1153.666667
#
#               2019-10  2019-11      2019-12      2020-01
# Metro
# Jacksonville  1181.75   1172.3  1182.222222  1186.888889
#
# [1 rows x 116 columns]

# %%
#Taking only the "months" columns
df_jax_mean=df_jax.groupby("Metro").mean().iloc[: , 3:]
df_jax_mean=df_jax_mean.T

# %%
df_jax_mean.columns=["Mean_Rent"]
df_jax_mean
# Out:
#            Mean_Rent
# 2010-09   706.000000
# 2010-10   726.000000
# 2010-11   733.000000
# 2010-12   736.000000
# 2011-01   752.000000
# ...              ...
# 2019-09  1153.666667
# 2019-10  1181.750000
# 2019-11  1172.300000
# 2019-12  1182.222222
# 2020-01  1186.888889
#
# [113 rows x 1 columns]

# %%
df_jax_max=df_jax.groupby("Metro").max().iloc[: , 6:].T

# %%
df_jax_max.columns=["Max_Rent"]

# %%
df_jax_max
# Out:
#          Max_Rent
# 2010-09     706.0
# 2010-10     726.0
# 2010-11     733.0
# 2010-12     736.0
# 2011-01     752.0
# ...           ...
# 2019-09    1456.0
# 2019-10    1472.0
# 2019-11    1482.0
# 2019-12    1475.0
# 2020-01    1473.0
#
# [113 rows x 1 columns]

# %%
df_jax_min=df_jax.groupby("Metro").min().iloc[: , 6:].T
df_jax_min.columns=["Min_Rent"]
df_jax_min
# Out:
#          Min_Rent
# 2010-09     706.0
# 2010-10     726.0
# 2010-11     733.0
# 2010-12     736.0
# 2011-01     752.0
# ...           ...
# 2019-09     799.0
# 2019-10     801.0
# 2019-11     819.0
# 2019-12     835.0
# 2020-01     854.0
#
# [113 rows x 1 columns]

# %%
df_jax_mean.shape
# Out:
# (113, 1)

# %%
plt.figure(figsize = (32, 16))

plt.plot(df_jax_max.index, df_jax_max["Max_Rent"], color='r')
plt.plot(df_jax_mean.index, df_jax_mean["Mean_Rent"], color='b')
plt.plot(df_jax_min.index, df_jax_min["Min_Rent"], color='g')

plt.xticks(np.arange(4, 112, 12), range(2011, 2020, 1), size=45)
#speificy where the first instance starts, 5th month in this case 
#plt.xticks(rotation=45, size=45)
plt.yticks(size=40)
plt.title("Max, Min and Average Zillow Rent Index ($) Over Time for Jacksonville", size=50)
plt.legend(['Max','Average','Min'], prop={'size': 40})
sns.set_style("whitegrid")
plt.grid(True, color = "grey", linewidth = "0.9", linestyle = "-.")
plt.show()

# %% [markdown]
# # Putting all 4 metro areas together

# %%
plt.figure(figsize = (32, 16))
plt.subplot(2,1,1) 
plt.plot(df_miami_max.index, df_miami_max["Max_Rent"], color='r')
plt.plot(df_miami_mean.index, df_miami_mean["Mean_Rent"], color='b')
plt.plot(df_miami_min.index, df_miami_min["Min_Rent"], color='g')

plt.xticks(np.arange(4,112, 12), range(2011, 2020, 1), size=45)
#speificy where the first instance starts, 5th month in this case 

plt.yticks(size=40)
plt.title("Max, Min and Average Zillow Rent Index ($) Over Time for Miami", size=50)
plt.legend(['Max','Average','Min'], prop={'size': 40})
sns.set_style("whitegrid")
plt.grid(True, color = "grey", linewidth = "0.9", linestyle = "-.")
plt.show()



plt.figure(figsize = (32, 16))
plt.subplot(2,1,2) 
plt.plot(df_orlando_max.index, df_orlando_max["Max_Rent"], color='r')
plt.plot(df_orlando_mean.index, df_orlando_mean["Mean_Rent"], color='b')
plt.plot(df_orlando_min.index, df_orlando_min["Min_Rent"], color='g')

plt.xticks(np.arange(4,112, 12), range(2011, 2020, 1), size=45)
#speificy where the first instance starts, 5th month in this case 
plt.yticks(size=40)
plt.title("Max, Min and Average Zillow Rent Index ($) Over Time for Orlando", size=50)
plt.legend(['Max','Average','Min'], prop={'size': 40})
sns.set_style("whitegrid")
plt.grid(True, color = "grey", linewidth = "0.9", linestyle = "-.")
plt.show()



plt.figure(figsize = (32, 16))
plt.subplot(2,1,1) 
plt.plot(df_tampa_max.index, df_tampa_max["Max_Rent"], color='r')
plt.plot(df_tampa_mean.index, df_tampa_mean["Mean_Rent"], color='b')
plt.plot(df_tampa_min.index, df_tampa_min["Min_Rent"], color='g')

plt.xticks(np.arange(4, 112, 12), range(2011, 2020, 1), size=45)
#speificy where the first instance starts, 5th month in this case 
plt.yticks(size=40)
plt.title("Max, Min and Average Zillow Rent Index ($) Over Time for Tampa", size=50)
plt.legend(['Max','Average','Min'], prop={'size': 40})
sns.set_style("whitegrid")
plt.grid(True, color = "grey", linewidth = "0.9", linestyle = "-.")
plt.show()


plt.figure(figsize = (32, 16))
plt.subplot(2,1,2) 
plt.plot(df_jax_max.index, df_jax_max["Max_Rent"], color='r')
plt.plot(df_jax_mean.index, df_jax_mean["Mean_Rent"], color='b')
plt.plot(df_jax_min.index, df_jax_min["Min_Rent"], color='g')

plt.xticks(np.arange(4, 112, 12), range(2011, 2020, 1), size=45)
#speificy where the first instance starts, 5th month in this case 
plt.yticks(size=40)
plt.title("Max, Min and Average Zillow Rent Index ($) Over Time for Jacksonville", size=50)
plt.legend(['Max','Average','Min'], prop={'size': 40})
sns.set_style("whitegrid")
plt.grid(True, color = "grey", linewidth = "0.9", linestyle = "-.")
plt.show()

# %% [markdown]
# # Average, Max and Min ZRI in Florida

# %%
plt.figure(figsize = (32, 16))
plt.plot(df_miami_mean.index, df_miami_mean["Mean_Rent"], color='r')
plt.plot(df_orlando_mean.index, df_orlando_mean["Mean_Rent"], color='g')
plt.plot(df_tampa_mean.index, df_tampa_mean["Mean_Rent"], color='b')
plt.plot(df_jax_mean.index, df_jax_mean["Mean_Rent"], color='purple')

plt.xticks(np.arange(4, 112, 12), range(2011, 2020, 1), size=45)
#speificy where the first instance starts, 5th month in this case 
plt.yticks(size=40)
plt.ylim(600, 1800)
plt.title("Average Zillow Rent Index ($) Over Time in the 4 Florida Metro Areas", size=50)
plt.legend(['Miami','Orlando','Tampa','Jacksonville'], prop={'size': 40})
sns.set_style("whitegrid")
plt.grid(True, color = "grey", linewidth = "0.9", linestyle = "-.")
plt.show()

# %%
plt.figure(figsize = (32, 16))
plt.plot(df_miami_max.index, df_miami_max["Max_Rent"], color='r')
plt.plot(df_orlando_max.index, df_orlando_max["Max_Rent"], color='g')
plt.plot(df_tampa_max.index, df_tampa_max["Max_Rent"], color='b')
plt.plot(df_jax_max.index, df_jax_max["Max_Rent"], color='purple')

plt.xticks(np.arange(4, 112, 12), range(2011, 2020, 1), size=45)
#speificy where the first instance starts, 5th month in this case 
plt.yticks(size=40)
#plt.ylim(600, 1800)
plt.title("Max Zillow Rent Index ($) Over Time in the 4 Florida Metro Areas", size=50)
plt.legend(['Miami','Orlando','Tampa','Jacksonville'], prop={'size': 40})
sns.set_style("whitegrid")
plt.grid(True, color = "grey", linewidth = "0.9", linestyle = "-.")
plt.show()

# %%
plt.figure(figsize = (32, 16))
plt.plot(df_miami_min.index, df_miami_min["Min_Rent"], color='r')
plt.plot(df_orlando_min.index, df_orlando_min["Min_Rent"], color='g')
plt.plot(df_tampa_min.index, df_tampa_min["Min_Rent"], color='b')
plt.plot(df_jax_min.index, df_jax_min["Min_Rent"], color='purple')

plt.xticks(np.arange(4, 112, 12), range(2011, 2020, 1), size=45)
#speificy where the first instance starts, 5th month in this case 
plt.yticks(size=40)
#plt.ylim(600, 1800)
plt.title("Min Zillow Rent Index ($) Over Time in the 4 Florida Metro Areas", size=50)
plt.legend(['Miami','Orlando','Tampa','Jacksonville'], prop={'size': 40})
sns.set_style("whitegrid")
plt.grid(True, color = "grey", linewidth = "0.9", linestyle = "-.")
plt.show()
