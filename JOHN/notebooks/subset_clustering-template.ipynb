# %%
import numpy as np
import pandas as pd
import json

from sklearn.preprocessing import MinMaxScaler, normalize
from sklearn.cluster import KMeans, AgglomerativeClustering

from PlottingFunctions import plot_inertia, plot_silhouette

# %%
pd.__version__
# Out:
# '1.3.5'

# %%
# %matplotlib inline
import plotly.express as px
import matplotlib.pyplot as plt

import dataframe_image as dfi

# %%
with open('../data/fl_florida_zip_codes_geo.min.json', 'r') as f:
    fla_shapefiles = json.load(f)

# %%
total_df = pd.read_csv('../data/total_df2.csv')
total_df_col_set = set(total_df.columns)
total_df
# Out:
#      zip_code  Monthly_Avg_Zip  FL_Unemployment  year  total_pop  households  \
# 0       33160      1866.833333         7.533333  2013      37674       19247
# 1       33025      1341.083333         7.533333  2013      57766       21206
# 2       33139      1842.666667         7.533333  2013      38066       20883
# 3       32256       947.750000         7.533333  2013      40024       18039
# 4       33009      1443.416667         7.533333  2013      39889       19125
# ..        ...              ...              ...   ...        ...         ...
# 636     33413      1447.583333         3.625000  2018      17473        5099
# 637     32204      1008.750000         3.625000  2018       7507        3825
# 638     32206       719.833333         3.625000  2018      16500        6767
# 639     33172      1747.571429         3.625000  2018      43083       13687
# 640     33605      1433.500000         3.625000  2018      17457        7041
#
#      male_pop  female_pop  median_age  male_under_5  ...  occupation_services  \
# 0       18472       19202        49.6           626  ...               2773.0
# 1       27852       29914        32.9          2143  ...               5448.0
# 2       22090       15976        38.1           981  ...               7164.0
# 3       18865       21159        32.7          1084  ...               2597.0
# 4       19256       20633        47.1          1213  ...               3977.0
# ..        ...         ...         ...           ...  ...                  ...
# 636      8493        8980        34.7           762  ...               1737.0
# 637      3352        4155        34.0           110  ...                454.0
# 638      7954        8546        37.4           431  ...               2075.0
# 639     21261       21822        41.4          1422  ...               4212.0
# 640      8207        9250        35.0           705  ...               1863.0
#
#      management_business_sci_arts_employed  sales_office_employed  \
# 0                                   7911.0                 4713.0
# 1                                  10806.0                 8948.0
# 2                                   9995.0                 4865.0
# 3                                  11070.0                 6247.0
# 4                                   5087.0                 4958.0
# ..                                     ...                    ...
# 636                                 2399.0                 2423.0
# 637                                 2078.0                  737.0
# 638                                 1476.0                 1366.0
# 639                                 6942.0                 7067.0
# 640                                 1388.0                 1781.0
#
#      in_grades_1_to_4  in_grades_5_to_8  in_grades_9_to_12  in_school  \
# 0                 935              1346                965       6471
# 1                2963              3682               3345      18163
# 2                 685               649                379       5387
# 3                1638              1598               1629      10962
# 4                1335              1020               1249       6495
# ..                ...               ...                ...        ...
# 636              1103               932                848       4875
# 637               176               201                231       1237
# 638               956               654                757       3743
# 639              1744              1907               1736       9732
# 640               692              1096                794       3907
#
#      in_undergrad_college  FLSTHPI_Yearly_Avg  median_pct_increase
# 0                    2019            291.6550             0.022971
# 1                    4987            291.6550             0.021003
# 2                    1906            291.6550             0.020404
# 3                    3429            291.6550             0.027058
# 4                    1885            291.6550             0.028284
# ..                    ...                 ...                  ...
# 636                  1107            444.3875             0.021767
# 637                   269            444.3875             0.012807
# 638                   809            444.3875             0.007578
# 639                  2452            444.3875            -0.041376
# 640                   728            444.3875             0.275356
#
# [641 rows x 219 columns]

# %%
total_df = total_df.set_index('zip_code')
total_df.shape
# Out:
# (641, 218)

# %%
cluster_subset_cols = ['million_dollar_housing_units', 'unemployed_pop', 
        'median_income', 'poverty', 
        'median_rent', 'percent_income_spent_on_rent']

# %%
subset_df = total_df[cluster_subset_cols]
subset_df.shape
# Out:
# (641, 6)

# %%
# %cd ../images
subdir = "tetris"
# !mkdir "tetris"
# %cd ../notebooks
# Out:
# /home/koz/koz/NYCDSA/Capstone/zillow_rent_index/JOHN/images
# /home/koz/koz/NYCDSA/Capstone/zillow_rent_index/JOHN/notebooks

# %%
######### K Means

# %%
km = KMeans(n_clusters = 3).fit(subset_df)

# %%
km_subset_df = subset_df.copy()
km_subset_df['km_cluster'] = km.labels_
km_subset_df
# Out:
#           million_dollar_housing_units  unemployed_pop  median_income  \
# zip_code
# 33160                              821          1260.0        45627.0
# 33025                                0          3667.0        51822.0
# 33139                              829          1197.0        46612.0
# 32256                               74          1943.0        54160.0
# 33009                               96          2823.0        33157.0
# ...                                ...             ...            ...
# 33413                                6           485.0        60635.0
# 32204                                0           273.0        40483.0
# 32206                               20           957.0        26565.0
# 33172                                0           989.0        46983.0
# 33605                               11           912.0        26954.0
#
#           poverty  median_rent  percent_income_spent_on_rent  km_cluster
# zip_code
# 33160      5120.0       1258.0                          34.0           0
# 33025      6940.0       1209.0                          36.7           0
# 33139      6672.0       1036.0                          31.8           0
# 32256      3937.0        862.0                          28.7           0
# 33009      8460.0        942.0                          39.3           2
# ...           ...          ...                           ...         ...
# 33413      1889.0       1275.0                          35.8           0
# 32204      2013.0        851.0                          31.2           2
# 32206      5398.0        579.0                          38.1           2
# 33172      6123.0       1347.0                          37.1           0
# 33605      6145.0        739.0                          39.3           2
#
# [641 rows x 7 columns]

# %%
total_merge_km = pd.merge(total_df, km_subset_df, on = km_subset_df.columns.tolist()[:-1] + ['zip_code'])

# %%
total_merge_km
# Out:
#           Monthly_Avg_Zip  FL_Unemployment  year  total_pop  households  \
# zip_code
# 33160         1866.833333         7.533333  2013      37674       19247
# 33025         1341.083333         7.533333  2013      57766       21206
# 33139         1842.666667         7.533333  2013      38066       20883
# 32256          947.750000         7.533333  2013      40024       18039
# 33009         1443.416667         7.533333  2013      39889       19125
# ...                   ...              ...   ...        ...         ...
# 33413         1447.583333         3.625000  2018      17473        5099
# 32204         1008.750000         3.625000  2018       7507        3825
# 32206          719.833333         3.625000  2018      16500        6767
# 33172         1747.571429         3.625000  2018      43083       13687
# 33605         1433.500000         3.625000  2018      17457        7041
#
#           male_pop  female_pop  median_age  male_under_5  male_5_to_9  ...  \
# zip_code                                                               ...
# 33160        18472       19202        49.6           626          654  ...
# 33025        27852       29914        32.9          2143         2102  ...
# 33139        22090       15976        38.1           981          513  ...
# 32256        18865       21159        32.7          1084         1124  ...
# 33009        19256       20633        47.1          1213          830  ...
# ...            ...         ...         ...           ...          ...  ...
# 33413         8493        8980        34.7           762          638  ...
# 32204         3352        4155        34.0           110          143  ...
# 32206         7954        8546        37.4           431          519  ...
# 33172        21261       21822        41.4          1422         1084  ...
# 33605         8207        9250        35.0           705          645  ...
#
#           management_business_sci_arts_employed  sales_office_employed  \
# zip_code
# 33160                                    7911.0                 4713.0
# 33025                                   10806.0                 8948.0
# 33139                                    9995.0                 4865.0
# 32256                                   11070.0                 6247.0
# 33009                                    5087.0                 4958.0
# ...                                         ...                    ...
# 33413                                    2399.0                 2423.0
# 32204                                    2078.0                  737.0
# 32206                                    1476.0                 1366.0
# 33172                                    6942.0                 7067.0
# 33605                                    1388.0                 1781.0
#
#           in_grades_1_to_4  in_grades_5_to_8  in_grades_9_to_12  in_school  \
# zip_code
# 33160                  935              1346                965       6471
# 33025                 2963              3682               3345      18163
# 33139                  685               649                379       5387
# 32256                 1638              1598               1629      10962
# 33009                 1335              1020               1249       6495
# ...                    ...               ...                ...        ...
# 33413                 1103               932                848       4875
# 32204                  176               201                231       1237
# 32206                  956               654                757       3743
# 33172                 1744              1907               1736       9732
# 33605                  692              1096                794       3907
#
#           in_undergrad_college  FLSTHPI_Yearly_Avg  median_pct_increase  \
# zip_code
# 33160                     2019            291.6550             0.022971
# 33025                     4987            291.6550             0.021003
# 33139                     1906            291.6550             0.020404
# 32256                     3429            291.6550             0.027058
# 33009                     1885            291.6550             0.028284
# ...                        ...                 ...                  ...
# 33413                     1107            444.3875             0.021767
# 32204                      269            444.3875             0.012807
# 32206                      809            444.3875             0.007578
# 33172                     2452            444.3875            -0.041376
# 33605                      728            444.3875             0.275356
#
#           km_cluster
# zip_code
# 33160              0
# 33025              0
# 33139              0
# 32256              0
# 33009              2
# ...              ...
# 33413              0
# 32204              2
# 32206              2
# 33172              0
# 33605              2
#
# [641 rows x 219 columns]

# %%
total_merge_km_group_by_cluster = total_merge_km.groupby('km_cluster')['median_pct_increase']\
    .aggregate(['mean'])

total_merge_km_group_by_cluster = total_merge_km_group_by_cluster.style\
    .hide_columns()\
    .set_caption(
    "Median YOY Rent Change By Cluster, KMeans"
)

total_merge_km_group_by_cluster
# Out:
# <style type="text/css">
# </style>
# <table id="T_b810b_">
#   <caption>Median YOY Rent Change By Cluster, KMeans</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b810b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b810b_row0_col0" class="data row0 col0" >0.041471</td>
#     </tr>
#     <tr>
#       <th id="T_b810b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b810b_row1_col0" class="data row1 col0" >0.036005</td>
#     </tr>
#     <tr>
#       <th id="T_b810b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b810b_row2_col0" class="data row2 col0" >0.040510</td>
#     </tr>
#   </tbody>
# </table>

# %%
image_name = "km_numbers.png"
dfi.export(total_merge_km_group_by_cluster,"../images/" + subdir + "/" + image_name)

# %%
total_merge_km.reset_index(inplace=True)
total_merge_km = total_merge_km.rename(columns = {'index':'zipcode'})

# %%
# fig = px.choropleth_mapbox(total_merge_km, geojson=fla_shapefiles, locations='zip_code', color='km_cluster',
#                            featureidkey='properties.ZCTA5CE10',
#                            color_continuous_scale="Viridis",
#                            mapbox_style="carto-positron",
#                            zoom=7.2, center = {"lat": 26.2, "lon": -81.0 },
#                            opacity=0.5,
#                           )
# fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
# fig.show()

# %%
image_name = "km_map.png"
fig.write_image("../images/" + subdir + "/" + image_name)

# %%
cluster_0_km = total_merge_km[total_merge_km['km_cluster'] == 0]
cluster_1_km = total_merge_km[total_merge_km['km_cluster'] == 1]
cluster_2_km = total_merge_km[total_merge_km['km_cluster'] == 2]

# %%
image_name = "km_scatter.png"
plt.figure()
plt.scatter(cluster_0_km['median_income'], cluster_0_km.Monthly_Avg_Zip, color="blue", label='0')
plt.scatter(cluster_1_km['median_income'], cluster_1_km.Monthly_Avg_Zip, color="orange", label='1')
plt.scatter(cluster_2_km['median_income'], cluster_2_km.Monthly_Avg_Zip, color="green", label='2')
plt.xlabel('Income per Capita')
plt.ylabel('Monthly Average Rent')
plt.legend()
plt.title('Income per capita vs. Monthly Average Rent')
plt.savefig("../images/" + subdir + "/" + image_name,  bbox_inches='tight')
plt.show()

# %%
########## agglomerative clustering ######

# %%
norm_subset_df = pd.DataFrame(normalize(subset_df,axis=0),columns=subset_df.columns)

# %%
norm_subset_df
# Out:
#      million_dollar_housing_units  unemployed_pop  median_income   poverty  \
# 0                        0.141017        0.024526       0.034865  0.025499
# 1                        0.000000        0.071379       0.039599  0.034563
# 2                        0.142391        0.023300       0.035618  0.033229
# 3                        0.012710        0.037821       0.041385  0.019608
# 4                        0.016489        0.054950       0.025336  0.042133
# ..                            ...             ...            ...       ...
# 636                      0.001031        0.009441       0.046333  0.009408
# 637                      0.000000        0.005314       0.030934  0.010025
# 638                      0.003435        0.018628       0.020299  0.026884
# 639                      0.000000        0.019251       0.035901  0.030494
# 640                      0.001889        0.017752       0.020596  0.030604
#
#      median_rent  percent_income_spent_on_rent
# 0       0.047640                      0.037660
# 1       0.045784                      0.040651
# 2       0.039233                      0.035223
# 3       0.032643                      0.031790
# 4       0.035673                      0.043531
# ..           ...                           ...
# 636     0.048283                      0.039654
# 637     0.032227                      0.034559
# 638     0.021926                      0.042202
# 639     0.051010                      0.041094
# 640     0.027985                      0.043531
#
# [641 rows x 6 columns]

# %%
ag = AgglomerativeClustering()
ag.set_params(n_clusters=3)
ag.fit(norm_subset_df)

ag_subset_df = subset_df.copy()
ag_subset_df['cluster'] = ag.labels_
ag_subset_df
# Out:
#           million_dollar_housing_units  unemployed_pop  median_income  \
# zip_code
# 33160                              821          1260.0        45627.0
# 33025                                0          3667.0        51822.0
# 33139                              829          1197.0        46612.0
# 32256                               74          1943.0        54160.0
# 33009                               96          2823.0        33157.0
# ...                                ...             ...            ...
# 33413                                6           485.0        60635.0
# 32204                                0           273.0        40483.0
# 32206                               20           957.0        26565.0
# 33172                                0           989.0        46983.0
# 33605                               11           912.0        26954.0
#
#           poverty  median_rent  percent_income_spent_on_rent  cluster
# zip_code
# 33160      5120.0       1258.0                          34.0        1
# 33025      6940.0       1209.0                          36.7        2
# 33139      6672.0       1036.0                          31.8        1
# 32256      3937.0        862.0                          28.7        0
# 33009      8460.0        942.0                          39.3        2
# ...           ...          ...                           ...      ...
# 33413      1889.0       1275.0                          35.8        0
# 32204      2013.0        851.0                          31.2        0
# 32206      5398.0        579.0                          38.1        0
# 33172      6123.0       1347.0                          37.1        0
# 33605      6145.0        739.0                          39.3        0
#
# [641 rows x 7 columns]

# %%
total_merge_ag = pd.merge(total_df, ag_subset_df, on = ag_subset_df.columns.tolist()[:-1] + ['zip_code'])
total_merge_ag
# Out:
#           Monthly_Avg_Zip  FL_Unemployment  year  total_pop  households  \
# zip_code
# 33160         1866.833333         7.533333  2013      37674       19247
# 33025         1341.083333         7.533333  2013      57766       21206
# 33139         1842.666667         7.533333  2013      38066       20883
# 32256          947.750000         7.533333  2013      40024       18039
# 33009         1443.416667         7.533333  2013      39889       19125
# ...                   ...              ...   ...        ...         ...
# 33413         1447.583333         3.625000  2018      17473        5099
# 32204         1008.750000         3.625000  2018       7507        3825
# 32206          719.833333         3.625000  2018      16500        6767
# 33172         1747.571429         3.625000  2018      43083       13687
# 33605         1433.500000         3.625000  2018      17457        7041
#
#           male_pop  female_pop  median_age  male_under_5  male_5_to_9  ...  \
# zip_code                                                               ...
# 33160        18472       19202        49.6           626          654  ...
# 33025        27852       29914        32.9          2143         2102  ...
# 33139        22090       15976        38.1           981          513  ...
# 32256        18865       21159        32.7          1084         1124  ...
# 33009        19256       20633        47.1          1213          830  ...
# ...            ...         ...         ...           ...          ...  ...
# 33413         8493        8980        34.7           762          638  ...
# 32204         3352        4155        34.0           110          143  ...
# 32206         7954        8546        37.4           431          519  ...
# 33172        21261       21822        41.4          1422         1084  ...
# 33605         8207        9250        35.0           705          645  ...
#
#           management_business_sci_arts_employed  sales_office_employed  \
# zip_code
# 33160                                    7911.0                 4713.0
# 33025                                   10806.0                 8948.0
# 33139                                    9995.0                 4865.0
# 32256                                   11070.0                 6247.0
# 33009                                    5087.0                 4958.0
# ...                                         ...                    ...
# 33413                                    2399.0                 2423.0
# 32204                                    2078.0                  737.0
# 32206                                    1476.0                 1366.0
# 33172                                    6942.0                 7067.0
# 33605                                    1388.0                 1781.0
#
#           in_grades_1_to_4  in_grades_5_to_8  in_grades_9_to_12  in_school  \
# zip_code
# 33160                  935              1346                965       6471
# 33025                 2963              3682               3345      18163
# 33139                  685               649                379       5387
# 32256                 1638              1598               1629      10962
# 33009                 1335              1020               1249       6495
# ...                    ...               ...                ...        ...
# 33413                 1103               932                848       4875
# 32204                  176               201                231       1237
# 32206                  956               654                757       3743
# 33172                 1744              1907               1736       9732
# 33605                  692              1096                794       3907
#
#           in_undergrad_college  FLSTHPI_Yearly_Avg  median_pct_increase  \
# zip_code
# 33160                     2019            291.6550             0.022971
# 33025                     4987            291.6550             0.021003
# 33139                     1906            291.6550             0.020404
# 32256                     3429            291.6550             0.027058
# 33009                     1885            291.6550             0.028284
# ...                        ...                 ...                  ...
# 33413                     1107            444.3875             0.021767
# 32204                      269            444.3875             0.012807
# 32206                      809            444.3875             0.007578
# 33172                     2452            444.3875            -0.041376
# 33605                      728            444.3875             0.275356
#
#           cluster
# zip_code
# 33160           1
# 33025           2
# 33139           1
# 32256           0
# 33009           2
# ...           ...
# 33413           0
# 32204           0
# 32206           0
# 33172           0
# 33605           0
#
# [641 rows x 219 columns]

# %%
total_merge_ag_group_by_cluster = total_merge_ag.groupby('cluster')['median_pct_increase']\
    .aggregate(['mean'])

total_merge_ag_group_by_cluster = total_merge_ag_group_by_cluster.style\
    .hide_columns()\
    .set_caption(
    "Median YOY Rent Change By Cluster, Agglomerative"
)

total_merge_ag_group_by_cluster
# Out:
# <style type="text/css">
# </style>
# <table id="T_9bbe3_">
#   <caption>Median YOY Rent Change By Cluster, Agglomerative</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9bbe3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9bbe3_row0_col0" class="data row0 col0" >0.043422</td>
#     </tr>
#     <tr>
#       <th id="T_9bbe3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9bbe3_row1_col0" class="data row1 col0" >0.028761</td>
#     </tr>
#     <tr>
#       <th id="T_9bbe3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9bbe3_row2_col0" class="data row2 col0" >0.038067</td>
#     </tr>
#   </tbody>
# </table>

# %%
image_name = "ag_numbers"
dfi.export(total_merge_ag_group_by_cluster,"../images/" + subdir + "/" + image_name)

# %%
total_merge_ag.reset_index(inplace=True)
total_merge_ag = total_merge_ag.rename(columns = {'index':'zipcode'})

# %%
# fig = px.choropleth_mapbox(total_merge_ag, geojson=fla_shapefiles, locations='zip_code', color='cluster',
#                            featureidkey='properties.ZCTA5CE10',
#                            color_continuous_scale="Viridis",
#                            mapbox_style="carto-positron",
#                            zoom=7.2, center = {"lat": 26.2, "lon": -81.0 },
#                            opacity=0.5,
#                           )
# fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
# fig.show()

# %%
image_name = "ag_map.png"
fig.write_image("../images/" + subdir + "/" + image_name)

# %%
cluster_0_ag = total_merge_ag[total_merge_ag['cluster'] == 0]
cluster_1_ag = total_merge_ag[total_merge_ag['cluster'] == 1]
cluster_2_ag = total_merge_ag[total_merge_ag['cluster'] == 2]

# %%
image_name = "ag_scatter.png"
plt.figure()
plt.scatter(cluster_0_ag['median_income'], cluster_0_ag.Monthly_Avg_Zip, color='blue', label='0' )
plt.scatter(cluster_1_ag['median_income'], cluster_1_ag.Monthly_Avg_Zip, color='orange', label='1')
plt.scatter(cluster_2_ag['median_income'], cluster_2_ag.Monthly_Avg_Zip, color='green', label='2')
plt.xlabel('Income per Capita')
plt.ylabel('Monthly Average Rent')
plt.legend()
plt.title('Income per capita vs. Monthly Average Rent')
plt.savefig("../images/" + subdir + "/" + image_name,  bbox_inches='tight')
plt.show()
