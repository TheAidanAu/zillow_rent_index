# %%
import numpy as np
import pandas as pd

# %%
total_df = pd.read_csv('../../JACOB/total_df.csv')
total_df_col_set = set(total_df.columns)

# %%
zips = total_df['zip_code'].unique()

# %%
total_df['Monthly_Avg_Zip'].eq(0).value_counts()
# Out:
# False    645
# Name: Monthly_Avg_Zip, dtype: int64

# %%
year_begin, year_end = 2013, 2018
pct_change = lambda a, b: ((b-a) / a)
pct_change_dict = {}

for z in zips:
    a_df = total_df[ total_df['zip_code'] == z ]
    pct_change_array = []
    for y in range( year_begin, year_end):
        a, b = a_df[a_df['year'] == y]['Monthly_Avg_Zip'].sum(), a_df[a_df['year'] == y+1]['Monthly_Avg_Zip'].sum()
        
        if a > 0 and b > 0:
            pct_change_array.append( pct_change(a, b) )
        
        if len(pct_change_array) > 0:
            pct_change_dict[z] = np.median(pct_change_array)

# %%
mpi_df = pd.DataFrame.from_dict(pct_change_dict, orient='index')
mpi_df.reset_index(inplace=True)
mpi_df = mpi_df.rename(columns = {'index':'zip_code', 0:'median_pct_increase' })
mpi_df
# Out:
#      zip_code  median_pct_increase
# 0       33160             0.022971
# 1       33025             0.021003
# 2       33139             0.020404
# 3       32256             0.027058
# 4       33009             0.028284
# ..        ...                  ...
# 118     32765             0.051919
# 119     33578             0.022998
# 120     34747             0.061024
# 121     33605             0.275356
# 122     33172            -0.041376
#
# [123 rows x 2 columns]

# %%
total_df2 = pd.merge(total_df,mpi_df, how='left', on='zip_code')
total_df2
# Out:
#      zip_code  Monthly_Avg_Zip  FL_Unemployment  year  total_pop  households  \
# 0       33160      1866.833333         7.533333  2013      37674       19247
# 1       33025      1341.083333         7.533333  2013      57766       21206
# 2       33139      1842.666667         7.533333  2013      38066       20883
# 3       32256       947.750000         7.533333  2013      40024       18039
# 4       33009      1443.416667         7.533333  2013      39889       19125
# ..        ...              ...              ...   ...        ...         ...
# 640     32828      1412.714286         3.625000  2018      65665       21327
# 641     33172      1747.571429         3.625000  2018      43083       13687
# 642     32827      1472.428571         3.625000  2018       9421        3498
# 643     33611      1349.666667         3.625000  2018      31791       14838
# 644     33605      1433.500000         3.625000  2018      17457        7041
#
#      male_pop  female_pop  median_age  male_under_5  ...  occupation_services  \
# 0       18472       19202        49.6           626  ...               2773.0
# 1       27852       29914        32.9          2143  ...               5448.0
# 2       22090       15976        38.1           981  ...               7164.0
# 3       18865       21159        32.7          1084  ...               2597.0
# 4       19256       20633        47.1          1213  ...               3977.0
# ..        ...         ...         ...           ...  ...                  ...
# 640     30928       34737        34.0          1569  ...               5583.0
# 641     21261       21822        41.4          1422  ...               4212.0
# 642      4524        4897        37.1            96  ...                628.0
# 643     15806       15985        41.5          1041  ...               2479.0
# 644      8207        9250        35.0           705  ...               1863.0
#
#      management_business_sci_arts_employed  sales_office_employed  \
# 0                                   7911.0                 4713.0
# 1                                  10806.0                 8948.0
# 2                                   9995.0                 4865.0
# 3                                  11070.0                 6247.0
# 4                                   5087.0                 4958.0
# ..                                     ...                    ...
# 640                                15472.0                 8267.0
# 641                                 6942.0                 7067.0
# 642                                 2362.0                  871.0
# 643                                 8571.0                 4273.0
# 644                                 1388.0                 1781.0
#
#      in_grades_1_to_4  in_grades_5_to_8  in_grades_9_to_12  in_school  \
# 0                 935              1346                965       6471
# 1                2963              3682               3345      18163
# 2                 685               649                379       5387
# 3                1638              1598               1629      10962
# 4                1335              1020               1249       6495
# ..                ...               ...                ...        ...
# 640              3153              3359               4530      21487
# 641              1744              1907               1736       9732
# 642               652               702                559       3109
# 643              1207              1227               1120       6596
# 644               692              1096                794       3907
#
#      in_undergrad_college  FLSTHPI_Yearly_Avg  median_pct_increase
# 0                    2019            291.6550             0.022971
# 1                    4987            291.6550             0.021003
# 2                    1906            291.6550             0.020404
# 3                    3429            291.6550             0.027058
# 4                    1885            291.6550             0.028284
# ..                    ...                 ...                  ...
# 640                  5829            444.3875                  NaN
# 641                  2452            444.3875            -0.041376
# 642                   720            444.3875                  NaN
# 643                  1476            444.3875                  NaN
# 644                   728            444.3875             0.275356
#
# [645 rows x 219 columns]

# %%
total_df2 = total_df2.dropna()
total_df2
# Out:
#      zip_code  Monthly_Avg_Zip  FL_Unemployment  year  total_pop  households  \
# 0       33160      1866.833333         7.533333  2013      37674       19247
# 1       33025      1341.083333         7.533333  2013      57766       21206
# 2       33139      1842.666667         7.533333  2013      38066       20883
# 3       32256       947.750000         7.533333  2013      40024       18039
# 4       33009      1443.416667         7.533333  2013      39889       19125
# ..        ...              ...              ...   ...        ...         ...
# 637     33413      1447.583333         3.625000  2018      17473        5099
# 638     32204      1008.750000         3.625000  2018       7507        3825
# 639     32206       719.833333         3.625000  2018      16500        6767
# 641     33172      1747.571429         3.625000  2018      43083       13687
# 644     33605      1433.500000         3.625000  2018      17457        7041
#
#      male_pop  female_pop  median_age  male_under_5  ...  occupation_services  \
# 0       18472       19202        49.6           626  ...               2773.0
# 1       27852       29914        32.9          2143  ...               5448.0
# 2       22090       15976        38.1           981  ...               7164.0
# 3       18865       21159        32.7          1084  ...               2597.0
# 4       19256       20633        47.1          1213  ...               3977.0
# ..        ...         ...         ...           ...  ...                  ...
# 637      8493        8980        34.7           762  ...               1737.0
# 638      3352        4155        34.0           110  ...                454.0
# 639      7954        8546        37.4           431  ...               2075.0
# 641     21261       21822        41.4          1422  ...               4212.0
# 644      8207        9250        35.0           705  ...               1863.0
#
#      management_business_sci_arts_employed  sales_office_employed  \
# 0                                   7911.0                 4713.0
# 1                                  10806.0                 8948.0
# 2                                   9995.0                 4865.0
# 3                                  11070.0                 6247.0
# 4                                   5087.0                 4958.0
# ..                                     ...                    ...
# 637                                 2399.0                 2423.0
# 638                                 2078.0                  737.0
# 639                                 1476.0                 1366.0
# 641                                 6942.0                 7067.0
# 644                                 1388.0                 1781.0
#
#      in_grades_1_to_4  in_grades_5_to_8  in_grades_9_to_12  in_school  \
# 0                 935              1346                965       6471
# 1                2963              3682               3345      18163
# 2                 685               649                379       5387
# 3                1638              1598               1629      10962
# 4                1335              1020               1249       6495
# ..                ...               ...                ...        ...
# 637              1103               932                848       4875
# 638               176               201                231       1237
# 639               956               654                757       3743
# 641              1744              1907               1736       9732
# 644               692              1096                794       3907
#
#      in_undergrad_college  FLSTHPI_Yearly_Avg  median_pct_increase
# 0                    2019            291.6550             0.022971
# 1                    4987            291.6550             0.021003
# 2                    1906            291.6550             0.020404
# 3                    3429            291.6550             0.027058
# 4                    1885            291.6550             0.028284
# ..                    ...                 ...                  ...
# 637                  1107            444.3875             0.021767
# 638                   269            444.3875             0.012807
# 639                   809            444.3875             0.007578
# 641                  2452            444.3875            -0.041376
# 644                   728            444.3875             0.275356
#
# [641 rows x 219 columns]

# %%
# %store total_df2
total_df2.to_csv('../data/total_df2.csv', index=False)
# Out:
# Stored 'total_df2' (DataFrame)
